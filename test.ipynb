# %%
import sqlite3

conn = sqlite3.connect("candidates.db")  # or campus.db
cursor = conn.cursor()

# Show tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())

# Replace with your actual table name
cursor.execute("SELECT * FROM candidates")
rows = cursor.fetchall()

for row in rows:
    print(row)

conn.close()
# Out:
# [('candidates',)]
# ('ba4fba3a-396e-4b02-99c9-024bb19a2d8f', 'Bharathi DevOps Engineer.pdf', 'Bharathi Alain', '["python", "ci/cd", "eks", "argocd", "grafana", "aws", "load balancer", "terraform", "kubernetes", "git", "vpc", "jenkins", "aws codedeploy", "helm", "aws codepipeline", "cloudtrail", "rds", "splunk", "ansible", "azure", "iam", "disaster recovery", "docker", "sonarqube", "microsoft excel", "prometheus", "ec2", "route53", "lambda"]', 6.0, '["Senior DevOps Engineer"]', '[]', 'Dynamic DevOps Engineer with experience in architecting scalable cloud ecosystems. Specialized in AWS, Kubernetes, Terraform, and CI/CD automation.', '2026-03-21T19:45:31.940711')
# ('249e4aed-67c8-432d-aa55-a1d0c3c69508', 'EVLYN MONICA JOSEPH.pdf', 'Evlyn Monica Joseph', '["loki", "github actions", "docker", "azure cloud resources", "microsoft excel", "prometheus", "terraform", "kubernetes", "postgresql", "grafana", "linux", "nginx", "jenkins", "bitbucket"]', 1.0, '["DevOps Engineer", "Software Engineer Trainee (DevOps)"]', '[{"degree": "B.E. Computer Science & Engineering", "institution": "Panimalar Institute of Technology, Chennai", "cgpa": 8.89, "duration": "2020-2024"}]', 'DevOps Engineer with experience in designing and maintaining CI/CD pipelines, managing containerized workloads, and implementing infrastructure automation.', '2026-03-21T19:46:53.581817')
# ('468acff1-9a08-4092-a230-56830a4cf06f', 'Pravin _Resume.pdf', 'Pravinkumar V', '["devops", "containerization", "ci/cd", "aws", "terraform", "kubernetes", "git", "jenkins", "maven", "cloudformation", "aws code pipeline", "ansible", "infrastructure as code (iac)", "linux", "docker", "sonarqube", "microsoft excel", "aws code deploy", "aws cdk"]', 4.0, '[{"title": "DevOps Engineer", "company": "Teleperformance-Chennai", "start_date": "Mar\'21 - Present"}]', '[{"degree": "Bachelor degree in Computer science", "university": "Madurai Kamaraj University, Madurai", "year": 2009}, {"degree": "Higher Secondary Education", "university": "Cathy Matriculation School, Madurai", "year": 2005}, {"degree": "SSLC", "university": "BVM School, Madurai", "year": 2003}]', '', '2026-03-21T19:48:53.211430')
# ('c4ae35e2-2ff1-4bea-99a8-f70925247252', 'Resume-latest.pdf', 'Ranjith Raj R', '["junit", "github actions", "github", "python", "grafana", "gitlab", "bitbucket", "azure devops", "instana", "bash", "gradle", "terraform", "kubernetes", "appcenter", "play console", "git", "azure repos", "new relic", "twistlock", "slack", "jenkins", "snyk", "cloudformation", "maven", "helm", "aws codepipeline", "ms secrets", "datadog", "xcode", "nowsecure", "maas360", "mend", "aws codecommit", "fastlane", "selenium", "owasp-zap", "openshift", "docker", "sonarqube", "microsoft excel", "mobsf", "testflight", "groovy", "prometheus"]', 4.0, '["DevOps Engineer", "Application Developer"]', '[{"institution": "Vellore Institute of Technology", "degree": "M.Tech, Software Engineering (Integrated)", "cgpa": 7.02}]', '', '2026-03-21T19:51:51.684138')
